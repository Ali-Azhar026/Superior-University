# %% [markdown]
# ## ¬@TASK [01]

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
    def display_info(self):
        print(f"Name: {self.name}, Age: {self.age}")


class Employee:
    def __init__(self, employee_id, position):
        self.employee_id = employee_id
        self.position = position
        
    def display_info(self):
        print(f"Employee Id: {self.employee_id}, Position: {self.position}")


class Staff(Person, Employee):
    def __init__(self, name, age, employee_id, position, department):
        Person.__init__(self, name, age)
        Employee.__init__(self, employee_id, position)
        self.department = department
        
    def additional_info(self):
        print(f"Department: {self.department}")


def read_employee_info(filename='Employee_details.txt'):
    staff_list = []
    try:
        with open(filename, 'r') as file:
            lines = file.readlines()
            for line in lines:
                name, age, employee_id, position, department = line.strip().split(',')
                staff = Staff(name, int(age), employee_id, position, department)
                staff_list.append(staff)
    except FileNotFoundError:
        print(f"The file {filename} does not exist.")
    return staff_list


def add_employee_info(name, age, employee_id, position, department, filename='Employee_details.txt'):
    staff = Staff(name, age, employee_id, position, department)
    with open(filename, 'a') as file:
        file.write(f"{staff.name},{staff.age},{staff.employee_id},{staff.position},{staff.department}\n")


def save_employee_info(staff_list, filename='Employee_details.txt'):
    with open(filename, 'w') as file:
        for staff in staff_list:
            file.write(f"{staff.name},{staff.age},{staff.employee_id},{staff.position},{staff.department}\n")


def main():
    filename = 'Employee_details.txt'
    while True:
        print("1. Add new employee")
        print("2. View all employees")
        print("3. Exit")
        choice = input("Enter your choice: ")

        if choice == '1':
            name = input("Enter name: ")
            age = int(input("Enter age: "))
            employee_id = input("Enter employee Id: ")
            position = input("Enter position: ")
            department = input("Enter department: ")
            add_employee_info(name, age, employee_id, position, department, filename)
            print("Employee information added successfully.")
        
        elif choice == '2':
            staff_list = read_employee_info(filename)
            if staff_list:
                print("Employee Details:")
                for staff in staff_list:
                    print(f"{staff.display_info()}, {staff.additional_info()}")
            else:
                print("Employee information is not available.")
        
        elif choice == '3':
            print("Exiting the program")
            break

        else:
            print("Invalid choice. Please try again.")


if __name__ == "__main__":
    main()
# Out:
# 1. Add new employee
# 2. View all employees
# 3. Exit
